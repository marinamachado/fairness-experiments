# %%
import numpy as np
import pandas as pd
import aif360
from aif360.datasets import AdultDataset, GermanDataset, CompasDataset, BankDataset, StandardDataset
from fairness_experiments import Experiment
from settings import classifiers_settings_test, final_classifiers_settings,classifiers_basic,lfr_settings,final_classifiers_settings_weights
from aif360.algorithms.preprocessing import DisparateImpactRemover,LFR
from dataset import Dataset,German,Titanic,Bank,Adult,Compas,Arrhythmia,Contraceptive,Alcohol,Canabis,Heroin

# %%
datasets = [Arrhythmia,Contraceptive,Alcohol,Canabis,Heroin,German,Titanic,Bank,Adult,Compas]
preproc = ['sem pré-processamento','DIR','RW','MSS','PS','US']

# %%
error = []

# %%
for data in datasets:
    results = pd.DataFrame()
    
    for p in preproc:
        df = data()
        
    try:
        if p != 'RW':
            exp_teste = Experiment(final_classifiers_settings,dataset_name=data.__name__, preprocessing_name=p, 
                 privileged_group='1.0')
        else:
            exp_teste = Experiment(final_classifiers_settings_weights,dataset_name=data.__name__, preprocessing_name=p, 
                 privileged_group='1.0')
        exp_teste.execute(df.X,df.y,df)
        results = results.append(exp_teste.report)
    except:
        error.append((data,p))
    results.to_csv(f'results/final-{data.__name__}')
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# (Heroin - US) - Classificador SVM2 (8/8) - Progresso Geral (83/83)
#    dataset preprocessing       clf_type  \
# 0   Heroin            US  Decision Tree
# 1   Heroin            US  Decision Tree
# 2   Heroin            US  Decision Tree
# 3   Heroin            US  Decision Tree
# 4   Heroin            US  Decision Tree
# ..     ...           ...            ...
# 78  Heroin            US           SVM2
# 79  Heroin            US           SVM2
# 80  Heroin            US           SVM2
# 81  Heroin            US           SVM2
# 82  Heroin            US           SVM2
#
#                                                params  accuracy  dif_accuracy  \
# 0   {'criterion': 'gini', 'max_depth': 3, 'splitte...  0.716676      0.042404
# 1   {'criterion': 'gini', 'max_depth': 3, 'splitte...  0.651401      0.069074
# 2   {'criterion': 'gini', 'max_depth': 7, 'splitte...  0.576595      0.031511
# 3   {'criterion': 'gini', 'max_depth': 7, 'splitte...  0.614299      0.091440
# 4   {'criterion': 'gini', 'max_depth': 11, 'splitt...  0.643979      0.066034
# ..                                                ...       ...           ...
# 78  {'gamma': 0.1, 'kernel': 'linear', 'random_sta...  0.537252      0.032843
# 79  {'gamma': 0.01, 'kernel': 'rbf', 'random_state...  0.812710      0.023776
# 80  {'gamma': 0.01, 'kernel': 'linear', 'random_st...  0.520797      0.028924
# 81  {'gamma': 0.001, 'kernel': 'rbf', 'random_stat...  0.771840      0.010439
# 82  {'gamma': 0.001, 'kernel': 'linear', 'random_s...  0.527692      0.029057
#
#     balanced_accuracy  dif_balanced_accuracy    recall  dif_recall  precision  \
# 0            0.631651               0.072431  0.510714    0.120428   0.277691
# 1            0.687660               0.101008  0.739286    0.202389   0.277509
# 2            0.568552               0.088638  0.557143    0.215548   0.197161
# 3            0.652611               0.020509  0.707143    0.080579   0.234130
# 4            0.624338               0.131868  0.596429    0.223969   0.242786
# ..                ...                    ...       ...         ...        ...
# 78           0.610296               0.055096  0.714286    0.102968   0.280702
# 79           0.497880               0.013313  0.050000    0.054749   0.560606
# 80           0.600632               0.042190  0.714286    0.060569   0.278951
# 81           0.512202               0.077467  0.142857    0.190805   0.585153
# 82           0.607630               0.042780  0.721429    0.095094   0.292974
#
#     dif_precision       fpr   dif_fpr  selection_rate  dif_selection_rate  \
# 0        0.132345  0.247413  0.051942        0.286526            0.060888
# 1        0.075833  0.363966  0.070783        0.419720            0.092560
# 2        0.063069  0.420040  0.053259        0.440403            0.065792
# 3        0.042043  0.401920  0.121596        0.447264            0.113819
# 4        0.125555  0.347752  0.039766        0.384691            0.028776
# ..            ...       ...       ...             ...                 ...
# 78       0.020995  0.493694  0.053862        0.526454            0.063040
# 79       0.563158  0.054239  0.028123        0.053608            0.032005
# 80       0.028262  0.513022  0.040514        0.542909            0.045237
# 81       0.589862  0.118454  0.035870        0.122080            0.059016
# 82       0.006162  0.506169  0.048019        0.538134            0.056928
#
#     dif_statistical_parity  dif_equal_opp  dif_avg_odds  \
# 0                 0.060888       0.120428      0.086185
# 1                 0.092560       0.202389      0.136586
# 2                 0.065792       0.215548      0.126910
# 3                 0.113819       0.080579      0.101087
# 4                 0.028776       0.223969      0.092102
# ..                     ...            ...           ...
# 78                0.063040       0.102968      0.078415
# 79                0.032005       0.054749      0.041436
# 80                0.045237       0.060569      0.050541
# 81                0.059016       0.190805      0.113338
# 82                0.056928       0.095094      0.071556
#
#     disparate_impacto_ratio
# 0                  0.749678
# 1                  1.245395
# 2                  0.915458
# 3                  1.080441
# 4                  0.915553
# ..                      ...
# 78                 1.269304
# 79                 0.220796
# 80                 1.143699
# 81                 0.289985
# 82                 1.292821
#
# [83 rows x 20 columns]
# IOError: [Errno 2] File /home/mfamachado/anaconda3/lib/python3.8/site-packages/aif360/datasets/../data/raw/german/german.data does not exist: '/home/mfamachado/anaconda3/lib/python3.8/site-packages/aif360/datasets/../data/raw/german/german.data'
# To use this class, please download the following files:
#
# 	https://archive.ics.uci.edu/ml/machine-learning-databases/statlog/german/german.data
# 	https://archive.ics.uci.edu/ml/machine-learning-databases/statlog/german/german.doc
#
# and place them, as-is, in the folder:
#
# 	/home/mfamachado/anaconda3/lib/python3.8/site-packages/aif360/data/raw/german
#
# Traceback (most recent call last):
#   File "/home/mfamachado/anaconda3/lib/python3.8/site-packages/aif360/datasets/german_dataset.py", line 78, in __init__
#     df = pd.read_csv(filepath, sep=' ', header=None, names=column_names,
#   File "/home/mfamachado/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 676, in parser_f
#     return _read(filepath_or_buffer, kwds)
#   File "/home/mfamachado/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 448, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/home/mfamachado/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 880, in __init__
#     self._make_engine(self.engine)
#   File "/home/mfamachado/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 1114, in _make_engine
#     self._engine = CParserWrapper(self.f, **self.options)
#   File "/home/mfamachado/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 1891, in __init__
#     self._reader = parsers.TextReader(src, **kwds)
#   File "pandas/_libs/parsers.pyx", line 374, in pandas._libs.parsers.TextReader.__cinit__
#   File "pandas/_libs/parsers.pyx", line 674, in pandas._libs.parsers.TextReader._setup_parser_source
# FileNotFoundError: [Errno 2] File /home/mfamachado/anaconda3/lib/python3.8/site-packages/aif360/datasets/../data/raw/german/german.data does not exist: '/home/mfamachado/anaconda3/lib/python3.8/site-packages/aif360/datasets/../data/raw/german/german.data'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mfamachado/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-15-16984c73bcfa>", line 5, in <module>
#     df = data()
#   File "/home/mfamachado/Documentos/fairness-experiments/dataset.py", line 83, in __init__
#     self.dataset = GermanDataset(label_name=self.label_name,
#   File "/home/mfamachado/anaconda3/lib/python3.8/site-packages/aif360/datasets/german_dataset.py", line 89, in __init__
#     sys.exit(1)
# SystemExit: 1
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mfamachado/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/mfamachado/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/mfamachado/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/mfamachado/anaconda3/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
# AttributeError: 'tuple' object has no attribute 'tb_frame'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/aif360/datasets/german_dataset.py in __init__(self, label_name, favorable_classes, protected_attribute_names, privileged_classes, instance_weights_name, categorical_features, features_to_keep, features_to_drop, na_values, custom_preprocessing, metadata)
#      77         try:
# ---> 78             df = pd.read_csv(filepath, sep=' ', header=None, names=column_names,
#      79                              na_values=na_values)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     879
# --> 880         self._make_engine(self.engine)
#     881
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File /home/mfamachado/anaconda3/lib/python3.8/site-packages/aif360/datasets/../data/raw/german/german.data does not exist: '/home/mfamachado/anaconda3/lib/python3.8/site-packages/aif360/datasets/../data/raw/german/german.data'
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-15-16984c73bcfa> in <module>
#       4     for p in preproc:
# ----> 5         df = data()
#       6
#
# ~/Documentos/fairness-experiments/dataset.py in __init__(self)
#      82
# ---> 83         self.dataset = GermanDataset(label_name=self.label_name,
#      84         protected_attribute_names=[self.protected_att_name],
#
# ~/anaconda3/lib/python3.8/site-packages/aif360/datasets/german_dataset.py in __init__(self, label_name, favorable_classes, protected_attribute_names, privileged_classes, instance_weights_name, categorical_features, features_to_keep, features_to_drop, na_values, custom_preprocessing, metadata)
#      88             import sys
# ---> 89             sys.exit(1)
#      90
#
# SystemExit: 1
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2035                     stb = ['An exception has occurred, use %tb to see '
#    2036                            'the full traceback.\n']
# -> 2037                     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2038                                                                      value))
#    2039                 else:
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in get_exception_only(self, etype, value)
#     821         value : exception value
#     822         """
# --> 823         return ListTB.structured_traceback(self, etype, value)
#     824
#     825     def show_exception_only(self, etype, evalue):
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     696             chained_exceptions_tb_offset = 0
#     697             out_list = (
# --> 698                 self.structured_traceback(
#     699                     etype, evalue, (etb, chained_exc_ids),
#     700                     chained_exceptions_tb_offset, context)
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1433         else:
#    1434             self.tb = tb
# -> 1435         return FormattedTB.structured_traceback(
#    1436             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1437
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1333         if mode in self.verbose_modes:
#    1334             # Verbose modes need a full traceback
# -> 1335             return VerboseTB.structured_traceback(
#    1336                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1337             )
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1190         """Return a nice text document describing the traceback."""
#    1191
# -> 1192         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1193                                                                tb_offset)
#    1194
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1148
#    1149
# -> 1150         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1151
#    1152         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %% [raw]
# results

# %%
results
