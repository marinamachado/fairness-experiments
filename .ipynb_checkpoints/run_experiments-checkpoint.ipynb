# %%
import numpy as np
import pandas as pd
import aif360
from aif360.datasets import AdultDataset, GermanDataset, CompasDataset, BankDataset, StandardDataset
from fairness_experiments import Experiment
from settings import classifiers_settings_test, final_classifiers_settings,classifiers_basic,lfr_settings,final_classifiers_settings_weights
from aif360.algorithms.preprocessing import DisparateImpactRemover,LFR
from dataset import Dataset,German,Titanic,Bank,Adult,Compas,Arrhythmia,Contraceptive,Alcohol,Canabis,Heroin

# %%
datasets = [Arrhythmia,Contraceptive,Alcohol,Canabis,Heroin,German,Titanic,Bank,Adult,Compas]
preproc = ['sem pré-processamento','DIR','RW','MSS','PS','US']

# %%
error = []

# %%
for data in datasets:
    results = pd.DataFrame()
    
    for p in preproc:
        df = data()
        
    try:
        if p != 'RW':
            exp_teste = Experiment(final_classifiers_settings,dataset_name=data.__name__, preprocessing_name=p, 
                 privileged_group='1.0')
        else:
            exp_teste = Experiment(final_classifiers_settings,dataset_name=data.__name__, preprocessing_name=p, 
                 privileged_group='1.0')
        exp_teste.execute(df.X,df.y,df)
        results = results.append(exp_teste.report)
        print(results)
    except:
        error.append((data,p))
    results.to_csv(f'results/final-{data.__name__}')
# Out:
# (Arrhythmia - RW) - Classificador KNN (0/8) - Progresso Geral (16/83)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-79248b26212d> in <module>
#       8         exp_teste = Experiment(final_classifiers_settings,dataset_name=data.__name__, preprocessing_name=p,
#       9              privileged_group='1.0')
# ---> 10         exp_teste.execute(df.X,df.y,df)
#      11         results = results.append(exp_teste.report)
#      12         print(results)
#
# ~/Documents/final-ic/fairness-experiments/fairness_experiments.py in execute(self, X, y, dataset, weights)
#     451
#     452                 # realiza o kfold
# --> 453                 result = kfold(clf, X, y, weights, self.preprocessing_name, dataset)
#     454
#     455                 # salva o resultado no relatório
#
# ~/Documents/final-ic/fairness-experiments/fairness_experiments.py in kfold(clf, X, y, weights, preprocess_name, dataset, k, stratified_by)
#     321         else:
#     322             # mudei os weigths aqui
# --> 323             clf.fit(x_train, y_train['target'], weights)
#     324
#     325         # Realiza as predições
#
# TypeError: fit() takes 3 positional arguments but 4 were given

# %% [raw]
# results

# %%
results
# Out:
#        dataset          preprocessing       clf_type  \
# 0   Arrhythmia  sem pré-processamento  Decision Tree
# 1   Arrhythmia  sem pré-processamento  Decision Tree
# 2   Arrhythmia  sem pré-processamento  Decision Tree
# 3   Arrhythmia  sem pré-processamento  Decision Tree
# 4   Arrhythmia  sem pré-processamento  Decision Tree
# ..         ...                    ...            ...
# 78  Arrhythmia                    DIR           SVM2
# 79  Arrhythmia                    DIR           SVM2
# 80  Arrhythmia                    DIR           SVM2
# 81  Arrhythmia                    DIR           SVM2
# 82  Arrhythmia                    DIR           SVM2
#
#                                                params  accuracy  dif_accuracy  \
# 0   {'criterion': 'gini', 'max_depth': 3, 'splitte...  0.735294      0.090278
# 1   {'criterion': 'gini', 'max_depth': 3, 'splitte...  0.750000      0.118056
# 2   {'criterion': 'gini', 'max_depth': 7, 'splitte...  0.735294      0.090278
# 3   {'criterion': 'gini', 'max_depth': 7, 'splitte...  0.808824      0.052083
# 4   {'criterion': 'gini', 'max_depth': 11, 'splitt...  0.735294      0.090278
# ..                                                ...       ...           ...
# 78  {'gamma': 0.1, 'kernel': 'linear', 'random_sta...  0.735294      0.208333
# 79  {'gamma': 0.01, 'kernel': 'rbf', 'random_state...  0.705882      0.329861
# 80  {'gamma': 0.01, 'kernel': 'linear', 'random_st...  0.735294      0.208333
# 81  {'gamma': 0.001, 'kernel': 'rbf', 'random_stat...  0.705882      0.329861
# 82  {'gamma': 0.001, 'kernel': 'linear', 'random_s...  0.735294      0.208333
#
#     balanced_accuracy  dif_balanced_accuracy    recall  dif_recall  precision  \
# 0            0.674967               0.128571  0.834783    0.108333   0.805153
# 1            0.611414               0.124256  0.940000    0.093750   0.763218
# 2            0.674967               0.128571  0.834783    0.108333   0.805153
# 3            0.717475               0.101935  0.940000    0.093750   0.818122
# 4            0.674967               0.128571  0.834783    0.108333   0.805153
# ..                ...                    ...       ...         ...        ...
# 78           0.680018               0.037202  0.834783    0.291667   0.811688
# 79           0.500000               0.000000  1.000000    0.000000   0.705882
# 80           0.680018               0.037202  0.834783    0.291667   0.811688
# 81           0.500000               0.000000  1.000000    0.000000   0.705882
# 82           0.680018               0.037202  0.834783    0.291667   0.811688
#
#     dif_precision       fpr   dif_fpr  selection_rate  dif_selection_rate  \
# 0        0.179735  0.484848  0.357143        0.735294            0.267361
# 1        0.241176  0.717172  0.154762        0.867647            0.149306
# 2        0.179735  0.484848  0.357143        0.735294            0.267361
# 3        0.195672  0.505051  0.181548        0.808824            0.145833
# 4        0.179735  0.484848  0.357143        0.735294            0.267361
# ..            ...       ...       ...             ...                 ...
# 78       0.204762  0.474747  0.366071        0.735294            0.385417
# 79       0.329861  1.000000  0.000000        1.000000            0.000000
# 80       0.204762  0.474747  0.366071        0.735294            0.385417
# 81       0.329861  1.000000  0.000000        1.000000            0.000000
# 82       0.204762  0.474747  0.366071        0.735294            0.385417
#
#     dif_statistical_parity  dif_equal_opp  dif_avg_odds  \
# 0                 0.267361       0.108333      0.228571
# 1                 0.149306       0.093750      0.052827
# 2                 0.267361       0.108333      0.228571
# 3                 0.145833       0.093750      0.137649
# 4                 0.267361       0.108333      0.228571
# ..                     ...            ...           ...
# 78                0.385417       0.291667      0.328869
# 79                0.000000       0.000000      0.000000
# 80                0.385417       0.291667      0.328869
# 81                0.000000       0.000000      0.000000
# 82                0.385417       0.291667      0.328869
#
#     disparate_impacto_ratio
# 0                  1.479798
# 1                  1.074074
# 2                  1.479798
# 3                  1.165501
# 4                  1.479798
# ..                      ...
# 78                 1.752381
# 79                 1.000000
# 80                 1.752381
# 81                 1.000000
# 82                 1.752381
#
# [166 rows x 20 columns]
